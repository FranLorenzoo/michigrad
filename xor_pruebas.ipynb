# %%
from train_xor import model, forward_single
from michigrad.visualize import show_graph
from michigrad.engine import Value

x = [Value(1), Value(0)]
y = 1

loss = forward_single(x, y)
loss
show_graph(loss)
# Out:
# Loss (single example, forward): 1.0728368281381457

# %%
model.zero_grad()
loss.backward()
show_graph(loss)
